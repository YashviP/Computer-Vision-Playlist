# %% [markdown]
# <a href="https://colab.research.google.com/github/YashviP/Computer-Vision-Playlist/blob/main/OpenCV/Morphological_transformations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Morphological transformations

# %% [markdown]
# - Erosion
# - Dilation
# - Opening
# - Closing
# - Morphological Gradient

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=490x383 at 0x7F699983DBD0>

# %% [markdown]
# # Erosion

# %%
import cv2
import numpy as np

img = cv2.imread('/content/micky.png',0)
kernel = np.ones((15,15),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)
cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=490x383 at 0x7F699981A8D0>

# %% [markdown]
# # Dilation

# %%
img = cv2.imread('/content/micky.png',0)
kernel = np.ones((15,15),np.uint8)
dilate = cv2.dilate(img,kernel,iterations = 1)
cv2_imshow(dilate)
# Out:
# <PIL.Image.Image image mode=L size=490x383 at 0x7F6998FCA190>

# %% [markdown]
# ## Dilation + Erosion

# %%
img = cv2.imread('/content/objects.png',0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1049x800 at 0x7F6998FAFC50>

# %%
kernel = np.ones((15,15), np.uint8)
img_dilation = cv2.dilate(img, kernel, iterations=1)
img_erode = cv2.erode(img_dilation,kernel, iterations=1)
cv2_imshow(img_erode)
# Out:
# <PIL.Image.Image image mode=L size=1049x800 at 0x7F6998FCA6D0>

# %% [markdown]
# ## Closing

# %%
kernel = np.ones((15,15), np.uint8)

# %%
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
cv2_imshow(closing)
# Out:
# <PIL.Image.Image image mode=L size=1049x800 at 0x7F6998FA55D0>

# %% [markdown]
# ## Opening

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=416x318 at 0x7F6998FEAF10>

# %%
kernel = np.ones((3,3), np.uint8)

# %%
img=cv2.imread("/content/fingerprint2.png",0)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
cv2_imshow(opening)
# Out:
# <PIL.Image.Image image mode=L size=416x318 at 0x7F699981A350>

# %% [markdown]
# ##  Morphological Gradient

# %%
img = cv2.imread('/content/micky.png',0)
kernel = np.ones((5,5),np.uint8)
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
cv2_imshow(gradient)
# Out:
# <PIL.Image.Image image mode=L size=490x383 at 0x7F6998F31ED0>
